# %%
import numpy as np
import pandas as pd

# %%
clothing=pd.read_csv(r"C:\Users\LENOVO\Desktop\Files\symbi\datasets-20220603T114254Z-001\datasets\Womens Clothing E-Commerce Reviews.csv")

# %%
clothing
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
clothing.shape
# Out:
# (23486, 11)

# %%
clothing.head(10)
# Out:
#    Unnamed: 0  Clothing ID  Age                                 Title  \
# 0           0          767   33                                   NaN
# 1           1         1080   34                                   NaN
# 2           2         1077   60               Some major design flaws
# 3           3         1049   50                      My favorite buy!
# 4           4          847   47                      Flattering shirt
# 5           5         1080   49               Not for the very petite
# 6           6          858   39                  Cagrcoal shimmer fun
# 7           7          858   39  Shimmer, surprisingly goes with lots
# 8           8         1077   24                            Flattering
# 9           9         1077   34                     Such a fun dress!
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# ...

# %%
clothing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
clothing._get_numeric_data()
# Out:
#        Unnamed: 0  Clothing ID  Age  Rating  Recommended IND  \
# 0               0          767   33       4                1
# 1               1         1080   34       5                1
# 2               2         1077   60       3                0
# 3               3         1049   50       5                1
# 4               4          847   47       5                1
# ...           ...          ...  ...     ...              ...
# 23481       23481         1104   34       5                1
# 23482       23482          862   48       3                1
# 23483       23483         1104   31       3                0
# 23484       23484         1084   28       3                1
# 23485       23485         1104   52       5                1
#
#        Positive Feedback Count
# 0                            0
# 1                            4
# 2                            0
# 3                            0
# 4                            6
# ...                        ...
# ...

# %%
categorical = [var for var in clothing.columns if clothing[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :\n\n', categorical)
# Out:
# There are 5 categorical variables
#
# The categorical variables are :
#
#  ['Title', 'Review Text', 'Division Name', 'Department Name', 'Class Name']

# %%
clothing[categorical].head(7)
# Out:
#                      Title                                        Review Text  \
# 0                      NaN  Absolutely wonderful - silky and sexy and comf...
# 1                      NaN  Love this dress!  it's sooo pretty.  i happene...
# 2  Some major design flaws  I had such high hopes for this dress and reall...
# 3         My favorite buy!  I love, love, love this jumpsuit. it's fun, fl...
# 4         Flattering shirt  This shirt is very flattering to all due to th...
# 5  Not for the very petite  I love tracy reese dresses, but this one is no...
# 6     Cagrcoal shimmer fun  I aded this in my basket at hte last mintue to...
#
#     Division Name Department Name Class Name
# 0       Initmates        Intimate  Intimates
# 1         General         Dresses    Dresses
# 2         General         Dresses    Dresses
# 3  General Petite         Bottoms      Pants
# 4         General            Tops    Blouses
# 5         General         Dresses    Dresses
# ...

# %%
clothing.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
clothing.dropna(axis=0,inplace=True)

# %%
clothing.isnull().sum()
# Out:
# Unnamed: 0                 0
# Clothing ID                0
# Age                        0
# Title                      0
# Review Text                0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# dtype: int64

# %%
X=clothing[['Title','Review Text','Rating']]
X=pd.DataFrame(X)
X
# Out:
#                                                    Title  \
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# 5                                Not for the very petite
# 6                                   Cagrcoal shimmer fun
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                              Review Text  Rating
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...

# %%
X.columns=['Titles','Reviews','Rating']
X
# Out:
#                                                   Titles  \
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# 5                                Not for the very petite
# 6                                   Cagrcoal shimmer fun
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                                  Reviews  Rating
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...

# %%
X.reset_index(inplace=True)

# %%
X
# Out:
#        index                                             Titles  \
# 0          2                            Some major design flaws
# 1          3                                   My favorite buy!
# 2          4                                   Flattering shirt
# 3          5                            Not for the very petite
# 4          6                               Cagrcoal shimmer fun
# ...      ...                                                ...
# 19657  23481                     Great dress for many occasions
# 19658  23482                         Wish it was made of cotton
# 19659  23483                              Cute, but see through
# 19660  23484  Very cute dress, perfect for summer parties an...
# 19661  23485                    Please make more like this one!
#
#                                                  Reviews  Rating
# 0      I had such high hopes for this dress and reall...       3
# 1      I love, love, love this jumpsuit. it's fun, fl...       5
# ...

# %%
X.drop(['index'],axis=1,inplace=True)

# %%
X
# Out:
#                                                   Titles  \
# 0                                Some major design flaws
# 1                                       My favorite buy!
# 2                                       Flattering shirt
# 3                                Not for the very petite
# 4                                   Cagrcoal shimmer fun
# ...                                                  ...
# 19657                     Great dress for many occasions
# 19658                         Wish it was made of cotton
# 19659                              Cute, but see through
# 19660  Very cute dress, perfect for summer parties an...
# 19661                    Please make more like this one!
#
#                                                  Reviews  Rating
# 0      I had such high hopes for this dress and reall...       3
# 1      I love, love, love this jumpsuit. it's fun, fl...       5
# 2      This shirt is very flattering to all due to th...       5
# ...

# %%
x= X['Reviews']

# %%
y=X['Rating']

# %%
y
# Out:
# 0        3
# 1        5
# 2        5
# 3        2
# 4        5
#         ..
# 19657    5
# 19658    3
# 19659    3
# 19660    3
# 19661    5
# Name: Rating, Length: 19662, dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 100, test_size = 0.3)

cv = CountVectorizer(min_df = 0.01, max_features = 500, stop_words = 'english') #1% / 300 occurences 
cv.fit(X_train)

X_train = cv.transform(X_train)
X_test = cv.transform(X_test)

# %%
model = MultinomialNB()

# %%
model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
X_train.shape,y_train.shape
# Out:
# ((13763, 441), (13763,))

# %%
model.score(X_test,y_test)
# Out:
# 0.5965417867435159

# %%
x= X['Reviews']
Y=pd.DataFrame(X['Rating'])

# %%
Y['Rating']=np.where(Y['Rating']>=3,'pos','neg')

# %%
Y
# Out:
#       Rating
# 0        pos
# 1        pos
# 2        pos
# 3        neg
# 4        pos
# ...      ...
# 19657    pos
# 19658    pos
# 19659    pos
# 19660    pos
# 19661    pos
#
# [19662 rows x 1 columns]

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(x, Y, random_state = 100, test_size = 0.3)

cv = CountVectorizer(min_df = 0.01, max_features = 500, stop_words = 'english') #1% / 300 occurences 
cv.fit(x2_train)

x2_train = cv.transform(x2_train)
x2_test = cv.transform(x2_test)

# %%
model.fit(x2_train,y2_train)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MultinomialNB()

# %%
x2_train.shape,y2_train.shape
# Out:
# ((13763, 441), (13763, 1))

# %%
model.score(x2_test,y2_test)
# Out:
# 0.8808272588574335

# %%
from sklearn.metrics import confusion_matrix # confusion matrix
y_test_pred = model.predict(x2_test)
confusion_matrix(y2_test, y_test_pred)
# Out:
# array([[ 343,  280],
#        [ 423, 4853]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
 # test accuracy
print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y2_test, y_test_pred)))
# Out:
# Model accuracy score: 0.8808

# %%
from sklearn.metrics import classification_report

print(classification_report(y2_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.45      0.55      0.49       623
#          pos       0.95      0.92      0.93      5276
#
#     accuracy                           0.88      5899
#    macro avg       0.70      0.74      0.71      5899
# weighted avg       0.89      0.88      0.89      5899

# %%
Y.value_counts()
# Out:
# Rating
# pos       17611
# neg        2051
# dtype: int64

# %%
# similar results with k-fold cross validation
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, x2_train, y2_train, cv = 10, scoring='accuracy')

print('Cross-validation scores:{}'.format(scores))
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
